# %%
# Init board as two-dimensional list
board = [[0 for _ in range(8)] for _ in range(8)]

# %%
fen_postions = [
    'rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1', # Starting pos 0
    'rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2', # Starting pos e4 c5 Nf3 1
    'rnbqkbnr/p1pqp2p/1q6/5Qq1/2Q4Q/8/PPPP1P1P/RNBQKBNR w KQkq - 0 1', # Starting pos many queens 2
    'R7/8/8/8/8/8/8/8 w - - 0 1', # Rook 3
    'R7/8/8/4R3/8/R7/8/8 w - - 0 1', # Rook 4
    'R7/8/4R3/2R1R3/8/R7/8/8 w - - 0 1', # Rook 5
    'R5r1/4b3/4R3/b1R1R3/7r/R7/2b5/8 w - - 0 1', # Rook 6
    '8/8/8/4b3/8/8/8/8 w - - 0 1', # Bishop 7
    '8/8/8/4b3/8/6b1/8/8 w - - 0 1', # Bishop 8
    '7b/8/8/4b3/8/6b1/8/8 w - - 0 1', # Bishop 9
    '8/8/8/4q3/8/8/8/8 w - - 0 1', # Queen 10
    '8/8/3nnn2/3nqn2/3nnn2/8/8/8 w - - 0 1', # Queen 11
    '8/8/8/3n4/8/8/8/8 w - - 0 1', # Knight 12
    'n6n/8/8/8/8/8/8/n6n w - - 0 1', # Knight 13
    '8/8/8/3k4/8/8/8/8 w - - 0 1', # King 14
    'K6K/8/8/8/8/8/8/K6K w - - 0 1', # King 15
    'rnbqkbnr/pppppppp/3QQ3/8/8/3qq3/PPPPPPPP/RNBQKBNR w KQkq - 0 1', # Starting position with check pawn takes 16
    'rnbqkbnr/1ppp1ppp/4p3/pP6/8/8/P1PPPPPP/RNBQKBNR w KQkq a6 0 3', # En passant on a6 17
    'rnbqkbnr/1ppp1pp1/8/pP2p1Pp/8/8/P1PPPP1P/RNBQKBNR w KQkq h6 0 5', # En passant on h6 18
    'rnbqkbnr/1p1p1pp1/8/pPpP2Pp/4p3/8/P1P1PP1P/RNBQKBNR w KQkq c6 0 7', # En passant on c6 19
    '8/2B5/5b2/n3b3/8/2B5/7n/8 w - - 0 1', # Bishop 20
    '8/2P1P3/1P1p1P2/2pn2p1/1P2NP2/2p1P1p1/3p1p2/8 w - - 0 1', # Knight 21
    '8/8/2PPP3/2PkP3/2ppp3/5PPP/5pKp/5ppp w - - 0 1', # King 22
    '8/8/2PPP3/2PqP3/2PPP3/8/8/8 w - - 0 1', # Queen 23
    'rnbqkbnr/p1pppppp/8/8/Pp1P4/8/1PP1PPPP/RNBQKBNR b KQkq a3 0 3', # En passant on a3 24
    'rnbqkbnr/p1pppp1p/8/3P4/Pp4pP/8/1PP1PPP1/RNBQKBNR b KQkq h3 0 5', # En passant on h3 25
    'rnbqkbnr/p1p1pppp/7P/8/1pPp4/8/PP1PPPP1/RNBQKBNR b KQkq c3 0 5', # En passant on c3 26
    'r3k2r/pppppppp/8/8/8/8/PPPPPPPP/R3K2R w KQkq - 0 1', # Castles check 27
    'rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RN1QK2R w KQkq - 0 1', # Castles check 28
    'r3k2r/pppppppp/5r1b/8/8/8/PP2P2P/R3K2R w KQkq - 0 1', # Castles check 29
    'r3k2r/pp2p2p/8/8/8/1BR5/PP2P2P/R3K2R w KQkq - 0 1', # Castles check 30
    '8/8/8/3k4/8/8/6B1/8 w - - 0 1', # Check check 31
    'Q2R4/8/8/3k4/2P2N2/8/6B1/8 w - - 0 1', # Check check 32
    'rnb1kbnr/pppppppp/8/q7/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1', # Check check 33
    'rnb1kbnr/pppppppp/8/q7/8/8/PPP1PPPP/RNBQKBNR w KQkq - 0 1', # Check check 34
    'rnb1k1nr/pppppppp/8/8/7b/8/PPPPPqPP/RNBQKBNR w KQkq - 0 1', # Mate 35
]

# %%
def fen_decode(fen: str):
    board = [['' for _ in range(8)] for _ in range(8)]
    parts = fen.split(' ')
    board_fen = parts[0]
    color = parts[1]
    castles = parts[2]
    en_passant = parts[3]

    rank_ranks = board_fen.split('/')
    for i, rank_fen in enumerate(rank_ranks):
        file_index = 0
        for char in rank_fen:
            if char.isdigit():  # Number of empty files
                file_index += int(char)
            else:  # Piece
                if char.islower():
                    board[i][file_index] = char
                    file_index += 1
                elif char.isupper():
                    board[i][file_index] = char
                    file_index += 1

    for i in range(8):
        for j in range(8):
            if board[i][j] == '':
                board[i][j] = '.'

    return board, castles, en_passant

# %%
board, castles, en_passant = fen_decode(fen_postions[35])

# %%
for i in range(8):
    for j in range(8):
        print(board[i][j], end='  ')
    print()
# Out:
# r  n  b  .  k  .  n  r
# p  p  p  p  p  p  p  p
# .  .  .  .  .  .  .  .
# .  .  .  .  .  .  .  .
# .  .  .  .  .  .  .  b
# .  .  .  .  .  .  .  .
# P  P  P  P  P  q  P  P
# R  N  B  Q  K  B  N  R

# %%
def check_rook(board: list, color: bool) -> list:
    rooks = []
    moves = []
    
    for i in range(len(board)): # Get all rooks into list
        for j in range(len(board[i])):
            if board[i][j] == 'R' and color == True: # White
                rooks.append([j, i])
            elif board[i][j] == 'r' and color == False: # Black
                rooks.append([j, i])
    
    for rook in rooks:
        for i in range(rook[0] + 1, 8): # Check moves to the right
            if board[rook[1]][i] == '.': # Empty square
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}-{chr(ord('a') + i)}{8 - rook[1]}")
            elif board[rook[1]][i].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + i)}{8 - rook[1]}")
                break
            elif board[rook[1]][i].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[rook[1]][i].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + i)}{8 - rook[1]}")
                break
            elif board[rook[1]][i].islower() and color == False: # Square occupied by black piece (black move)
                break
        
        for i in range(rook[0] - 1, -1, -1): # Check moves to the left
            if board[rook[1]][i] == '.': # Empty square
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}-{chr(ord('a') + i)}{8 - rook[1]}")
            elif board[rook[1]][i].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + i)}{8 - rook[1]}")
                break
            elif board[rook[1]][i].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[rook[1]][i].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + i)}{8 - rook[1]}")
                break
            elif board[rook[1]][i].islower() and color == False: # Square occupied by black piece (black move)
                break
        
        for i in range(rook[1] + 1, 8): # Check moves to the bottom
            if board[i][rook[0]] == '.': # Empty square
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}-{chr(ord('a') + rook[0])}{8 - i}")
            elif board[i][rook[0]].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + rook[0])}{8 - i}")
                break
            elif board[i][rook[0]].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[i][rook[0]].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + rook[0])}{8 - i}")
                break
            elif board[i][rook[0]].islower() and color == False: # Square occupied by black piece (black move)
                break

        for i in range(rook[1] - 1, -1, -1): # Check moves to the top
            if board[i][rook[0]] == '.': # Empty square
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}-{chr(ord('a') + rook[0])}{8 - i}")
            elif board[i][rook[0]].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + rook[0])}{8 - i}")
                break
            elif board[i][rook[0]].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[i][rook[0]].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"R{chr(ord('a') + rook[0])}{8 - rook[1]}x{chr(ord('a') + rook[0])}{8 - i}")
                break
            elif board[i][rook[0]].islower() and color == False: # Square occupied by black piece (black move)
                break
    
    return moves

# %%
def check_bishop(board: list, color: bool) -> list:
    bishops = []
    moves = []
    
    for i in range(len(board)): # Get all bishops into list
        for j in range(len(board[i])):
            if board[i][j] == 'B' and color == True: # White
                bishops.append([j, i])
            elif board[i][j] == 'b' and color == False: # Black
                bishops.append([j, i])
    
    for bishop in bishops:
        for i in range(1, 8):
            if i < 8 - bishop[0] and i < 8 - bishop[1]: # Check moves to the bottom right
                if board[bishop[1] + i][bishop[0] + i] == '.': # Empty square
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}-{chr(ord('a') + i + bishop[0])}{8 - bishop[1] - i}")
                elif board[bishop[1] + i][bishop[0] + i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') + i + bishop[0])}{8 - bishop[1] - i}")
                    break
                elif board[bishop[1] + i][bishop[0] + i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[bishop[1] + i][bishop[0] + i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') + i + bishop[0])}{8 - bishop[1] - i}")
                    break
                elif board[bishop[1] + i][bishop[0] + i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break
            
        for i in range(1, 8):
            if i < 8 - bishop[0] and i < bishop[1] + 1: # Check moves to the top right
                if board[bishop[1] - i][bishop[0] + i] == '.': # Empty square
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}-{chr(ord('a') + i + bishop[0])}{8 - bishop[1] + i}")
                elif board[bishop[1] - i][bishop[0] + i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') + i + bishop[0])}{8 - bishop[1] + i}")
                    break
                elif board[bishop[1] - i][bishop[0] + i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[bishop[1] - i][bishop[0] + i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') + i + bishop[0])}{8 - bishop[1] + i}")
                    break
                elif board[bishop[1] - i][bishop[0] + i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break
        
        for i in range(1, 8):
            if i < bishop[0] + 1 and i < 8 - bishop[1]: # Check moves to the bottom left
                if board[bishop[1] + i][bishop[0] - i] == '.': # Empty square
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}-{chr(ord('a') - i + bishop[0])}{8 - bishop[1] - i}")
                elif board[bishop[1] + i][bishop[0] - i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') - i + bishop[0])}{8 - bishop[1] - i}")
                    break
                elif board[bishop[1] + i][bishop[0] - i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[bishop[1] + i][bishop[0] - i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') - i + bishop[0])}{8 - bishop[1] - i}")
                    break
                elif board[bishop[1] + i][bishop[0] - i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break

        for i in range(1, 8):
            if i < bishop[0] + 1 and i < bishop[1] + 1: # Check moves to the top left
                if board[bishop[1] - i][bishop[0] - i] == '.': # Empty square
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}-{chr(ord('a') - i + bishop[0])}{8 - bishop[1] + i}")
                elif board[bishop[1] - i][bishop[0] - i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') - i + bishop[0])}{8 - bishop[1] + i}")
                    break
                elif board[bishop[1] - i][bishop[0] - i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[bishop[1] - i][bishop[0] - i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"B{chr(ord('a') + bishop[0])}{8 - bishop[1]}x{chr(ord('a') - i + bishop[0])}{8 - bishop[1] + i}")
                    break
                elif board[bishop[1] - i][bishop[0] - i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break
    
    return moves

# %%
def check_knight(board: list, color: bool) -> list:
    knights = []
    moves = []
    
    for i in range(len(board)): # Get all knights into list
        for j in range(len(board[i])):
            if board[i][j] == 'N' and color == True: # White
                knights.append([j, i])
            elif board[i][j] == 'n' and color == False: # Black
                knights.append([j, i])
    
    for knight in knights: 
        if knight[0] + 2 <= 7 and knight[1] - 1 >= 0: # Check moves to 2 squares to the right and 1 square to the top
            if board[knight[1] - 1][knight[0] + 2] == '.': # Empty square 
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] + 2)}{8 - knight[1] + 1}")
            elif (board[knight[1] - 1][knight[0] + 2].islower() and color == True) or (board[knight[1] - 1][knight[0] + 2].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] + 2)}{8 - knight[1] + 1}")
        
        if knight[0] + 2 <= 7 and knight[1] + 1 <= 7: # Check moves to 2 squares to the right and 1 square to the bottom
            if board[knight[1] + 1][knight[0] + 2] == '.': # Empty square 
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] + 2)}{8 - knight[1] - 1}")
            elif (board[knight[1] + 1][knight[0] + 2].islower() and color == True) or (board[knight[1] + 1][knight[0] + 2].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] + 2)}{8 - knight[1] - 1}")
        
        if knight[0] + 1 <= 7 and knight[1] + 2 <= 7: # Check moves to 1 square to the right and 2 squares to the bottom
            if board[knight[1] + 2][knight[0] + 1] == '.': # Empty square 
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] + 1)}{8 - knight[1] - 2}")
            elif (board[knight[1] + 2][knight[0] + 1].islower() and color == True) or (board[knight[1] + 2][knight[0] + 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] + 1)}{8 - knight[1] - 2}")
        
        if knight[0] - 1 >= 0 and knight[1] + 2 <= 7: # Check moves to 1 square to the left and 2 squares to the bottom
            if board[knight[1] + 2][knight[0] - 1] == '.': # Empty square 
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] - 1)}{8 - knight[1] - 2}")
            elif (board[knight[1] + 2][knight[0] - 1].islower() and color == True) or (board[knight[1] + 2][knight[0] - 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] - 1)}{8 - knight[1] - 2}")

        if knight[0] - 2 >= 0 and knight[1] + 1 <= 7: # Check moves to 2 squares to the left and 1 square to the bottom
            if board[knight[1] + 1][knight[0] - 2] == '.': # Empty square
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] - 2)}{8 - knight[1] - 1}")
            elif (board[knight[1] + 1][knight[0] - 2].islower() and color == True) or (board[knight[1] + 1][knight[0] - 2].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] - 2)}{8 - knight[1] - 1}")
        
        if knight[0] - 2 >= 0 and knight[1] - 1 >= 0: # Check moves to 2 squares to the left and 1 square to the top
            if board[knight[1] - 1][knight[0] - 2] == '.': # Empty square
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] - 2)}{8 - knight[1] + 1}")
            elif (board[knight[1] - 1][knight[0] - 2].islower() and color == True) or (board[knight[1] - 1][knight[0] - 2].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] - 2)}{8 - knight[1] + 1}")

        if knight[0] - 1 >= 0 and knight[1] - 2 >= 0: # Check moves to 1 square to the left and 2 squares to the top
            if board[knight[1] - 2][knight[0] - 1] == '.': # Empty square
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] - 1)}{8 - knight[1] + 2}")
            elif (board[knight[1] - 2][knight[0] - 1].islower() and color == True) or (board[knight[1] - 2][knight[0] - 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] - 1)}{8 - knight[1] + 2}")
        
        if knight[0] + 1 <= 7 and knight[1] - 2 >= 0: # Check moves to 1 square to the right and 2 squares to the top
            if board[knight[1] - 2][knight[0] + 1] == '.': # Empty square
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}-{chr(ord('a') + knight[0] + 1)}{8 - knight[1] + 2}")
            elif (board[knight[1] - 2][knight[0] + 1].islower() and color == True) or (board[knight[1] - 2][knight[0] + 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"N{chr(ord('a') + knight[0])}{8 - knight[1]}x{chr(ord('a') + knight[0] + 1)}{8 - knight[1] + 2}")
        
    return moves

# %%
def check_king(board: list, color: bool) -> list:
    kings = []
    moves = []
    
    for i in range(len(board)): # Get all kings into list
        for j in range(len(board[i])):
            if board[i][j] == 'K' and color == True: # White
                kings.append([j, i])
            elif board[i][j] == 'k' and color == False: # Black
                kings.append([j, i])

    for king in kings:
        if king[0] + 1 <= 7: # Check moves to the right
            if board[king[1]][king[0] + 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] + 1)}{8 - king[1]}")
            elif (board[king[1]][king[0] + 1].islower() and color == True) or (board[king[1]][king[0] + 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] + 1)}{8 - king[1]}")
            
        if king[0] - 1 >= 0: # Check moves to the left
            if board[king[1]][king[0] - 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] - 1)}{8 - king[1]}")
            elif (board[king[1]][king[0] - 1].islower() and color == True) or (board[king[1]][king[0] - 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] - 1)}{8 - king[1]}")
        
        if king[1] + 1 <= 7: # Check moves to the bottom
            if board[king[1] + 1][king[0]] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0])}{8 - king[1] - 1}")
            elif (board[king[1] + 1][king[0]].islower() and color == True) or (board[king[1] + 1][king[0]].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0])}{8 - king[1] - 1}")
        
        if king[1] - 1 >= 0: # Check moves to the top
            if board[king[1] - 1][king[0]] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0])}{8 - king[1] + 1}")
            elif (board[king[1] - 1][king[0]].islower() and color == True) or (board[king[1] - 1][king[0]].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0])}{8 - king[1] + 1}")
        
        if king[0] + 1 <= 7 and king[1] + 1 <= 7: # Check moves to the bottom right
            if board[king[1] + 1][king[0] + 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] + 1)}{8 - king[1] - 1}")
            elif (board[king[1] + 1][king[0] + 1].islower() and color == True) or (board[king[1] + 1][king[0] + 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] + 1)}{8 - king[1] - 1}")

        if king[0] + 1 <= 7 and king[1] - 1 >= 0: # Check moves to the top right
            if board[king[1] - 1][king[0] + 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] + 1)}{8 - king[1] + 1}")
            elif (board[king[1] - 1][king[0] + 1].islower() and color == True) or (board[king[1] - 1][king[0] + 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] + 1)}{8 - king[1] + 1}")

        if king[0] - 1 >= 0 and king[1] + 1 <= 7: # Check moves to the bottom left
            if board[king[1] + 1][king[0] - 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] - 1)}{8 - king[1] - 1}")
            elif (board[king[1] + 1][king[0] - 1].islower() and color == True) or (board[king[1] + 1][king[0] - 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] - 1)}{8 - king[1] - 1}")
        
        if king[0] - 1 >= 0 and king[1] - 1 >= 0: # Check moves to the top left
            if board[king[1] - 1][king[0] - 1] == '.': # Empty square
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}-{chr(ord('a') + king[0] - 1)}{8 - king[1] + 1}")
            elif (board[king[1] - 1][king[0] - 1].islower() and color == True) or (board[king[1] - 1][king[0] - 1].isupper() and color == False): # Square occupied by piece of another color
                moves.append(f"K{chr(ord('a') + king[0])}{8 - king[1]}x{chr(ord('a') + king[0] - 1)}{8 - king[1] + 1}")
    
    return moves

# %%
def check_queen(board: list, color: bool) -> list:
    queens = []
    moves = []
    
    for i in range(len(board)): # Get all queens into list
        for j in range(len(board[i])):
            if board[i][j] == 'Q' and color == True: # White
                queens.append([j, i])
            elif board[i][j] == 'q' and color == False: # Black
                queens.append([j, i])
    
    for queen in queens:
        for i in range(queen[0] + 1, 8): # Check moves to the right
            if board[queen[1]][i] == '.': # Empty square
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + i)}{8 - queen[1]}")
            elif board[queen[1]][i].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i)}{8 - queen[1]}")
                break
            elif board[queen[1]][i].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[queen[1]][i].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i)}{8 - queen[1]}")
                break
            elif board[queen[1]][i].islower() and color == False: # Square occupied by black piece (black move)
                break
        
        for i in range(queen[0] - 1, -1, -1): # Check moves to the left
            if board[queen[1]][i] == '.': # Empty square
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + i)}{8 - queen[1]}")
            elif board[queen[1]][i].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i)}{8 - queen[1]}")
                break
            elif board[queen[1]][i].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[queen[1]][i].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i)}{8 - queen[1]}")
                break
            elif board[queen[1]][i].islower() and color == False: # Square occupied by black piece (black move)
                break
        
        for i in range(queen[1] + 1, 8): # Check moves to the bottom
            if board[i][queen[0]] == '.': # Empty square
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + queen[0])}{8 - i}")
            elif board[i][queen[0]].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + queen[0])}{8 - i}")
                break
            elif board[i][queen[0]].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[i][queen[0]].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + queen[0])}{8 - i}")
                break
            elif board[i][queen[0]].islower() and color == False: # Square occupied by black piece (black move)
                break

        for i in range(queen[1] - 1, -1, -1): # Check moves to the top
            if board[i][queen[0]] == '.': # Empty square
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + queen[0])}{8 - i}")
            elif board[i][queen[0]].islower() and color == True: # Square occupied by black piece (white move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + queen[0])}{8 - i}")
                break
            elif board[i][queen[0]].isupper() and color == True: # Square occupied by white piece (white move)
                break
            elif board[i][queen[0]].isupper() and color == False: # Square occupied by white piece (black move)
                moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + queen[0])}{8 - i}")
                break
            elif board[i][queen[0]].islower() and color == False: # Square occupied by black piece (black move)
                break
    
        for i in range(1, 8):
            if i < 8 - queen[0] and i < 8 - queen[1]: # Check moves to the bottom right
                if board[queen[1] + i][queen[0] + i] == '.': # Empty square
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + i + queen[0])}{8 - queen[1] - i}")
                elif board[queen[1] + i][queen[0] + i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i + queen[0])}{8 - queen[1] - i}")
                    break
                elif board[queen[1] + i][queen[0] + i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[queen[1] + i][queen[0] + i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i + queen[0])}{8 - queen[1] - i}")
                    break
                elif board[queen[1] + i][queen[0] + i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break
            
        for i in range(1, 8):
            if i < 8 - queen[0] and i < queen[1] + 1: # Check moves to the top right
                if board[queen[1] - i][queen[0] + i] == '.': # Empty square
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') + i + queen[0])}{8 - queen[1] + i}")
                elif board[queen[1] - i][queen[0] + i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i + queen[0])}{8 - queen[1] + i}")
                    break
                elif board[queen[1] - i][queen[0] + i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[queen[1] - i][queen[0] + i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') + i + queen[0])}{8 - queen[1] + i}")
                    break
                elif board[queen[1] - i][queen[0] + i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break
        
        for i in range(1, 8):
            if i < queen[0] + 1 and i < 8 - queen[1]: # Check moves to the bottom left
                if board[queen[1] + i][queen[0] - i] == '.': # Empty square
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') - i + queen[0])}{8 - queen[1] - i}")
                elif board[queen[1] + i][queen[0] - i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') - i + queen[0])}{8 - queen[1] - i}")
                    break
                elif board[queen[1] + i][queen[0] - i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[queen[1] + i][queen[0] - i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') - i + queen[0])}{8 - queen[1] - i}")
                    break
                elif board[queen[1] + i][queen[0] - i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break

        for i in range(1, 8):
            if i < queen[0] + 1 and i < queen[1] + 1: # Check moves to the top left
                if board[queen[1] - i][queen[0] - i] == '.': # Empty square
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}-{chr(ord('a') - i + queen[0])}{8 - queen[1] + i}")
                elif board[queen[1] - i][queen[0] - i].islower() and color == True: # Square occupied by black piece (white move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') - i + queen[0])}{8 - queen[1] + i}")
                    break
                elif board[queen[1] - i][queen[0] - i].isupper() and color == True: # Square occupied by white piece (white move)
                    break
                elif board[queen[1] - i][queen[0] - i].isupper() and color == False: # Square occupied by white piece (black move)
                    moves.append(f"Q{chr(ord('a') + queen[0])}{8 - queen[1]}x{chr(ord('a') - i + queen[0])}{8 - queen[1] + i}")
                    break
                elif board[queen[1] - i][queen[0] - i].islower() and color == False: # Square occupied by black piece (black move)
                    break
            else:
                break

    return moves

# %%
def check_pawn(board: list, color: bool) -> list:
    pawns = []
    moves = []
    
    for i in range(len(board)): # Get all pawns into list
        for j in range(len(board[i])):
            if board[i][j] == 'P' and color == True: # White
                pawns.append([j, i])
            elif board[i][j] == 'p' and color == False: # Black
                pawns.append([j, i])
    
    for pawn in pawns:
        if color:
            if board[pawn[1] - 1][pawn[0]] == '.':
                moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}-{chr(ord('a') + pawn[0])}{8 - pawn[1] + 1}")
            if pawn[1] == 6 and board[pawn[1] - 2][pawn[0]] == '.' and board[pawn[1] - 1][pawn[0]] == '.':
                moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}-{chr(ord('a') + pawn[0])}{8 - pawn[1] + 2}")
            if pawn[0] != 0:
                if board[pawn[1] - 1][pawn[0] - 1] != '.' and board[pawn[1] - 1][pawn[0] - 1].islower():
                    moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}x{chr(ord('a') + pawn[0] - 1)}{8 - pawn[1] + 1}")
            if pawn[0] != 7:
                if board[pawn[1] - 1][pawn[0] + 1] != '.' and board[pawn[1] - 1][pawn[0] + 1].islower():
                    moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}x{chr(ord('a') + pawn[0] + 1)}{8 - pawn[1] + 1}")
        else:
            if board[pawn[1] + 1][pawn[0]] == '.':
                moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}-{chr(ord('a') + pawn[0])}{8 - pawn[1] - 1}")
            if pawn[1] == 1 and board[pawn[1] + 2][pawn[0]] == '.' and board[pawn[1] + 1][pawn[0]] == '.':
                moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}-{chr(ord('a') + pawn[0])}{8 - pawn[1] - 2}")
            if pawn[0] != 0:
                if board[pawn[1] + 1][pawn[0] - 1] != '.' and board[pawn[1] + 1][pawn[0] - 1].isupper():
                    moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}x{chr(ord('a') + pawn[0] - 1)}{8 - pawn[1] - 1}")
            if pawn[0] != 7:
                if board[pawn[1] + 1][pawn[0] + 1] != '.' and board[pawn[1] + 1][pawn[0] + 1].isupper():
                    moves.append(f"P{chr(ord('a') + pawn[0])}{8 - pawn[1]}x{chr(ord('a') + pawn[0] + 1)}{8 - pawn[1] - 1}")
    
    return moves

# %%
def check_en_passant(board: list, color: bool, en_passant: str) -> list:
    pawns = []
    moves = []
    
    for i in range(len(board)): # Get all pawns into list
        for j in range(len(board[i])):
            if board[i][j] == 'P' and color == True: # White
                pawns.append([j, i])
            elif board[i][j] == 'p' and color == False: # Black
                pawns.append([j, i])
    
    if en_passant != '-':
        if en_passant[0] == 'a':
            if color and board[3][1] == 'P':
                moves.append("Pb5xa6")
            elif color == False and board[4][1] == 'p':
                moves.append("Pb4xa3")
        elif en_passant[0] == 'h':
            if color and board[3][6] == 'P':
                moves.append("Pg5xh6")
            elif color == False and board[4][6] == 'p':
                moves.append("Pg4xah3")
        else:
            if color and board[3][ord(en_passant[0]) - ord('a') + 1] == 'P':
                moves.append(f"P{chr(ord(en_passant[0]) + 1)}5x{en_passant}")
            if color and board[3][ord(en_passant[0]) - ord('a') - 1] == 'P':
                moves.append(f"P{chr(ord(en_passant[0]) - 1)}5x{en_passant}")
            if color == False and board[4][ord(en_passant[0]) - ord('a') + 1] == 'p':
                moves.append(f"P{chr(ord(en_passant[0]) + 1)}4x{en_passant}")
            if color == False and board[4][ord(en_passant[0]) - ord('a') - 1] == 'p':
                moves.append(f"P{chr(ord(en_passant[0]) - 1)}4x{en_passant}")

    return moves

# %%
def check_castles(board: list, color: bool, castles: str) -> list:
    moves = []
    moves_opposite = []
    can_castles = True

    moves_opposite.extend(check_rook(board, not color))
    moves_opposite.extend(check_bishop(board, not color))
    moves_opposite.extend(check_queen(board, not color))
    moves_opposite.extend(check_knight(board, not color))
    moves_opposite.extend(check_king(board, not color))
    moves_opposite.extend(check_pawn(board, not color))

    if color:
        if 'K' in castles:
            if board[7][4] == 'K' and board[7][5] == '.' and board[7][6] == '.' and board[7][7] == 'R':
                for move in moves_opposite:
                    if move[-2:] in ('e1', 'f1', 'g1'):
                        can_castles = False
                        break
                if can_castles:
                    moves.append('O-O')
        if 'Q' in castles:
            if board[7][4] == 'K' and board[7][1] == '.' and board[7][2] == '.' and board[7][3] == '.' and board[7][0] == 'R':
                for move in moves_opposite:
                    if move[-2:] in ('c1', 'd1', 'e1'):
                        can_castles = False
                        break
                if can_castles:
                    moves.append('O-O-O')
    else:
        if 'k' in castles:
            if board[0][4] == 'k' and board[0][5] == '.' and board[0][6] == '.' and board[0][7] == 'r':
                for move in moves_opposite:
                    if move[-2:] in ('e8', 'f8', 'g8'):
                        can_castles = False
                        break
                if can_castles:
                    moves.append('O-O')
        if 'q' in castles:
            if board[0][4] == 'k' and board[0][1] == '.' and board[0][2] == '.' and board[0][3] == '.' and board[0][0] == 'r':
                for move in moves_opposite:
                    if move[-2:] in ('c8', 'd8', 'e8'):
                        can_castles = False
                        break
                if can_castles:
                    moves.append('O-O-O')

    return moves

# %%
def check_checks(board: list, color: bool) -> bool:
    moves_opposite = []
    kings = []
    check = False
    
    for i in range(len(board)): # Get all kings into list
        for j in range(len(board[i])):
            if board[i][j] == 'K' and color == True: # White
                kings.append([j, i])
            elif board[i][j] == 'k' and color == False: # Black
                kings.append([j, i])

    moves_opposite.extend(check_rook(board, not color))
    moves_opposite.extend(check_bishop(board, not color))
    moves_opposite.extend(check_queen(board, not color))
    moves_opposite.extend(check_knight(board, not color))
    moves_opposite.extend(check_king(board, not color))
    moves_opposite.extend(check_pawn(board, not color))

    for move in moves_opposite:
        if move[-2:] == f"{chr(ord('a') + kings[0][0])}{8 - kings[0][1]}":
            check = True

    return check

# %%
def handle_checks(board: list, color: bool, moves: list) -> list:
    kings = []
    moves_to_remove = []

    for i in range(len(board)): # Get all kings into list
        for j in range(len(board[i])):
            if board[i][j] == 'K' and color == True: # White
                kings.append([j, i])
            elif board[i][j] == 'k' and color == False: # Black
                kings.append([j, i])
    
    check = check_checks(board, color)

    if check == True:
        moves = check_king(board, color)
        for move in moves:
            temp_board = [sublist.copy() for sublist in board]
            temp_board[kings[0][1]][kings[0][0]] = '.'
            if color:
                temp_board[8 - int(move[-1])][ord(move[-2]) - ord('a')] = 'K'

                if check_checks(temp_board, color):
                    moves_to_remove.append(move)
            else:
                temp_board[8 - int(move[-1])][ord(move[-2]) - ord('a')] = 'k'

                if check_checks(temp_board, color):
                    moves_to_remove.append(move)

    for move in moves_to_remove:
        if move in moves:
            moves.remove(move)

    return moves

# %%
def handle_checks2(board: list, color: bool, moves: list) -> list:
    moves_to_remove = []

    for move in moves:
        temp_board = [sublist.copy() for sublist in board]
        temp_board[8 - int(move[2])][ord(move[1]) - ord('a')] = '.'
        if color:
            temp_board[8 - int(move[-1])][ord(move[-2]) - ord('a')] = move[0]

            if check_checks(temp_board, color):
                moves_to_remove.append(move)
        else:
            temp_board[8 - int(move[-1])][ord(move[-2]) - ord('a')] = move[0].lower()

            if check_checks(temp_board, color):
                moves_to_remove.append(move)

    for move in moves_to_remove:
        if move in moves:
            moves.remove(move)

    return moves

# %%
all_moves = []
on_move = True
all_moves.extend(check_rook(board, on_move))
all_moves.extend(check_bishop(board, on_move))
all_moves.extend(check_knight(board, on_move))
all_moves.extend(check_king(board, on_move))
all_moves.extend(check_queen(board, on_move))
all_moves.extend(check_pawn(board, on_move))
all_moves.extend(check_en_passant(board, on_move, en_passant))
all_moves.extend(check_castles(board, on_move, castles))
all_moves = handle_checks2(board, on_move, all_moves)
for move in all_moves:
    print(move)

# %%
import chess

board_lib = chess.Board(fen_postions[35])
for move in board_lib.legal_moves:
    print(move)
# board_lib.legal_moves
